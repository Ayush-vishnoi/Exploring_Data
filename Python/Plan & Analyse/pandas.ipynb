# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import plotly.express as px
import seaborn as sns

# %%
df=pd.read_csv("FINAL_DATASET_cleaned.csv")

# %%
df.shape
# Out:
# (235990, 17)

# %%
df.dtypes
# Out:
# state                   object
# district                object
# crop                    object
# crop_year                int64
# season                  object
# area                   float64
# production             float64
# yield                  float64
# latitude               float64
# longitude              float64
# avgtemp_c              float64
# humidity_perc            int64
# ph                     float64
# organic_carbon_g_kg    float64
# clay_g_kg                int64
# sand_g_kg                int64
# total_rainfall_mm      float64
# dtype: object

# %%
df.head()
# Out:
#          state    district      crop  crop_year       season    area  \
# 0       kerala      idukki  Arecanut       2006  Whole Year   3416.0
# 1        assam       baksa  Arecanut       2006  Whole Year   4136.0
# 2  west bengal     birbhum  Arecanut       1999  Whole Year     14.0
# 3        assam  bongaigaon  Arecanut       2012  Rabi         1559.0
# 4        assam    tinsukia  Arecanut       2006  Whole Year   1720.0
#
#    production  yield   latitude  longitude  avgtemp_c  humidity_perc   ph  \
# 0      5041.0   1.48   9.873821  77.013261       21.8             87  5.3
# 1      3174.0   0.77  26.666007  91.341537       20.2             48  5.4
# 2        15.0   1.07  23.951730  87.661595       24.7             72  6.1
# 3      2155.0   1.38  26.346255  90.613392       16.6             75  5.4
# 4      1160.0   0.67  27.584271  95.625565       20.1             46  5.2
#
#    organic_carbon_g_kg  clay_g_kg  sand_g_kg  total_rainfall_mm
# 0                 52.5        321        386            2690.34
# 1                 19.5        273        390            1536.47
# 2                 30.2        231        369            1247.31
# 3                 18.7        298        421            2124.63
# 4                 35.0        272        443            1974.57

# %%
df["crop"]
# Out:
# 0               Arecanut
# 1               Arecanut
# 2               Arecanut
# 3               Arecanut
# 4               Arecanut
#                ...
# 235985    other oilseeds
# 235986    other oilseeds
# 235987    other oilseeds
# 235988    other oilseeds
# 235989    other oilseeds
# Name: crop, Length: 235990, dtype: object
